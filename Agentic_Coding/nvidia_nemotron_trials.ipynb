# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

completion = client.chat.completions.create(
  model="nvidia/nemotron-3-ultra-550b-a55b",
  messages=[{"role":"user","content":"How to use the NVIDIA NeMo Free API in Python?"}],
  temperature=1,
  top_p=0.95,
  max_tokens=16384,
  extra_body={"chat_template_kwargs":{"enable_thinking":True},"reasoning_budget":16384},
  stream=True
)

for chunk in completion:
  if not chunk.choices:
    continue
  reasoning = getattr(chunk.choices[0].delta, "reasoning_content", None)
  if reasoning:
    print(reasoning, end="")
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")
# Out:
# The user is asking how to use the "NVIDIA NeMo Free API in Python".
# I need to clarify what "NeMo Free API" refers to.
# 1.  **NeMo Framework (Open Source):** This is a Python library installed locally (`pip install nemo_toolkit`). It's free and open source (Apache 2.0).
# 2.  **NVIDIA NGC / NIM (Inference Microservices):** NVIDIA offers hosted API endpoints (often free tiers/credits) for models like Nemotron, Llama, etc., accessible via OpenAI-compatible APIs.
# 3.  **NeMo Guardrails:** An open-source toolkit for guardrails, usable locally or via a server.
#
# There isn't a single official product named exactly "NVIDIA NeMo Free API" that is a cloud-hosted REST API specifically branded "NeMo API" in the same way OpenAI has an API.
# However, NVIDIA *does* provide **NVIDIA NIM (NVIDIA Inference Microservices)** which serves NeMo-trained models (like Nemotron 3 Ultra, Nemotron 4, etc.) via an OpenAI-compatible API endpoint. They often have a free tier on `build.nvidia.com` or via NGC.
#
# I should structure the answer to cover the most likely interpretations:
# 1.  **Local Development (NeMo Toolkit):** The core open-source library.
# 2.  **Cloud Hosted Inference (NVIDIA NIM / build.nvidia.com):** The "Free API" experience (OpenAI compatible).
# 3.  **NeMo Guardrails:** If they mean the guardrails server.As of **mid-2024**, there is **no single official product named "NVIDIA NeMo Free API"** hosted by NVIDIA as a permanent, free-to-use public REST endpoint (like `api.openai.com`).
#
# However, developers typically mean one of three things when asking this. Here is how to use each in Python:
#
# ---
#
# ### 1. NVIDIA NIM (Inference Microservices) — **The "Free Cloud API" Experience**
# This is the closest thing to a "Free API." NVIDIA hosts optimized models (Nemotron 3 Ultra, Llama 3, Mistral, etc.) on **`build.nvidia.com`** and provides **OpenAI-compatible API endpoints**.
# *   **Cost:** Free tier available (rate limited) with an NVIDIA account (NGC).
# *   **Protocol:** OpenAI Python SDK compatible.
#
# #### Step-by-Step Setup
# 1.  Go to **[build.nvidia.com](https://build.nvidia.com/explore/discover)**.
# 2.  Sign in / Create NGC Account.
# 3.  Select a model (e.g., **Nemotron 3 Ultra**, **Llama 3 70B**, **Mistral 7B**).
# 4.  Click **"Get API Key"** (usually top right).
# 5.  Copy the **Base URL** and **API Key**.
#
# #### Python Code (Using `openai` SDK)
# ```python
# import os
# from openai import OpenAI
#
# # 1. Configure credentials
# # Get these from build.nvidia.com -> Your Model -> "Code Sample" / "API Key"
# API_KEY = "nvapi-xxxx-your-key-here"  # Starts with nvapi-
# BASE_URL = "https://integrate.api.nvidia.com/v1"  # Standard NIM endpoint
#
# client = OpenAI(
#     base_url=BASE_URL,
#     api_key=API_KEY
# )
#
# # 2. Call the model (Chat Completion)
# completion = client.chat.completions.create(
#     model="nvidia/nemotron-3-ultra",  # Or "meta/llama3-70b", "mistralai/mistral-7b-instruct-v0.2"
#     messages=[
#         {"role": "system", "content": "You are a helpful assistant."},
#         {"role": "user", "content": "Write a python function for fibonacci sequence."}
#     ],
#     temperature=0.2,
#     top_p=0.7,
#     max_tokens=1024,
#     stream=True  # Recommended for better UX
# )
#
# # 3. Handle Streaming Response
# print("Response: ")
# for chunk in completion:
#     if chunk.choices[0].delta.content is not None:
#         print(chunk.choices[0].delta.content, end="", flush=True)
#
# print("\n--- Done ---")
# ```
#
# > **Note:** Model names follow the format `namespace/model-name` (e.g., `nvidia/nemotron-3-ultra`, `meta/llama3-70b`). Check the specific model page on `build.nvidia.com` for the exact string.
#
# ---
#
# ### 2. NeMo Framework (Open Source) — **Run Locally (Truly Free)**
# If you have a GPU (local machine, Colab, RunPod, Lambda, etc.), you run the **actual NeMo Toolkit** locally. No API keys, no rate limits, no internet required after download.
#
# **Install:**
# ```bash
# # Core toolkit (PyTorch Lightning based)
# pip install nemo_toolkit[all]
#
# # For LLMs specifically (requires newer versions)
# pip install "nemo_toolkit[llm]"
# ```
#
# **Python Usage (Inference with a local `.nemo` checkpoint):**
# ```python
# import nemo.collections.llm as llm
#
# # 1. Load a model (e.g., from Hugging Face or local .nemo file)
# # This downloads weights automatically if not cached
# model = llm.GPTModel.from_pretrained("nvidia/nemotron-3-8b-chat-4k")
#
# # 2. Setup Trainer (for inference, 1 GPU, precision bf16)
# import lightning.pytorch as pl
# trainer = pl.Trainer(
#     devices=1,
#     accelerator="gpu",
#     precision="bf16-mixed",
#     logger=False
# )
#
# # 3. Run Inference
# # NeMo 2.0+ uses the `generate` method or the `generate` function in `nemo.collections.llm.api`
# from nemo.collections.llm.api import generate
#
# prompts = ["Write a haiku about GPUs:", "Translate 'Hello' to French:"]
#
# # generate() handles tokenization, sampling, and detokenization
# results = generate(
#     model=model,
#     trainer=trainer,
#     prompts=prompts,
#     max_new_tokens=100,
#     temperature=0.7,
#     top_p=0.9
# )
#
# for prompt, result in zip(prompts, results):
#     print(f"Prompt: {prompt}")
#     print(f"Output: {result}\n")
# ```
#
# ---
#
# ### 3. NeMo Guardrails — **Guardrails as a Local Server (API)**
# If you want to put **safety/guardrails** in front of an LLM (local or remote) and expose it as an API, use **NeMo Guardrails**. It runs a FastAPI server locally.
#
# **Install:**
# ```bash
# pip install nemoguardrails
# ```
#
# **1. Create a Config Folder (`config/`):**
# ```text
# config/
# ├── config.yml
# ├── prompts.yml
# └── rails.co
# ```
#
# **`config/config.yml`**:
# ```yaml
# models:
#   - type: main
#     engine: openai
#     model: "nvidia/nemotron-3-ultra" # Or your local model via vLLM/TGI endpoint
#     parameters:
#       base_url: "https://integrate.api.nvidia.com/v1"
#       api_key: "env: NVIDIA_API_KEY" # Reads from env var
# ```
#
# **`config/rails.co`** (Colang - define rules):
# ```colang
# define user express greeting
#   "hi"
#   "hello"
#
# define flow greeting
#   user express greeting
#   bot express greeting
#
# define bot express greeting
#   "Hello! How can I help you today?"
# ```
#
# **2. Run the Server:**
# ```bash
# # Set your key
# export NVIDIA_API_KEY="nvapi-xxxx"
#
# # Start server (defaults to port 8000)
# nemoguardrails server --config=./config --host=0.0.0.0 --port=8000
# ```
#
# **3. Call it from Python (Client Side):**
# ```python
# import requests
#
# url = "http://localhost:8000/v1/chat/completions"
# headers = {"Content-Type": "application/json"}
# data = {
#     "messages": [{"role": "user", "content": "Hi there!"}],
#     "temperature": 0.5
# }
#
# response = requests.post(url, json=data, headers=headers)
# print(response.json()['choices'][0]['message']['content'])
# ```
#
# ---
#
# ### Summary: Which one do you need?
#
# | Goal | Solution | Cost | Hardware Req |
# | :--- | :--- | :--- | :--- |
# | **"I want to call Nemotron/Llama via HTTP for free right now"** | **NVIDIA NIM (`build.nvidia.com`)** | Free Tier (Rate Limited) | None (Cloud) |
# | **"I want to fine-tune / train / run inference offline on my GPU"** | **NeMo Framework (`nemo_toolkit`)** | Free (Apache 2.0) | **NVIDIA GPU (VRAM >= 8GB+)** |
# | **"I need PII masking / Topic control / Jailbreak protection as an API"** | **NeMo Guardrails (Local Server)** | Free (Apache 2.0) | CPU / GPU (Lightweight) |
# | **"I want to deploy a custom NeMo model as a production API"** | **NeMo + TRT-LLM / vLLM / TGI + Triton/FastAPI** | Free (Self-hosted) | **NVIDIA GPU (A100/H100 recommended)** |
#
# ### Pro Tip: Local "API" feeling with `vLLM`
# If you downloaded a NeMo model (`.nemo` checkpoint) and want an **OpenAI-compatible API server locally** (faster than raw PyTorch), convert it to Hugging Face format and serve with **vLLM**:
#
# ```bash
# # 1. Convert NeMo -> HF (one time)
# python -m nemo.collections.llm.export --checkpoint_path ./my_model.nemo --output_path ./my_model_hf
#
# # 2. Serve with vLLM (OpenAI API compatible)
# vllm serve ./my_model_hf --tensor-parallel-size 1 --port 8000
# ```
# Then use standard `openai` python client pointing to `http://localhost:8000/v1`.
